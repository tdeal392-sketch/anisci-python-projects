# %% [markdown]
# <a href="https://colab.research.google.com/github/tdeal392-sketch/-week1-broiler-checker/blob/main/week1_broiler_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow Animal Science + Tech")
name = input("Your Name: ")
Age = input(" Your Age: ")
print(f"Wellcome {name}, Day 1 complete!")
# Out:
# Hellow Animal Science + Tech
# Your Name: SAM
#  Your Age: 39
# Wellcome SAM, Day 1 complete!

# %%
print(" hello world it's Priase Backed to the Programming  ")
Aa = input(" print: ")
# Out:
#  hello world it's Priase Backed to the Programming
#  print: (" hello world it's Priase Backed to the Programming  ")
